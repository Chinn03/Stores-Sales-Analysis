# %%
import pandas as pd
Df = pd.read_csv("/content/SampleSuperstore.csv")

# %%
Df.head()
# Out:
#         Ship Mode    Segment        Country  ... Quantity Discount    Profit
# 0    Second Class   Consumer  United States  ...        2     0.00   41.9136
# 1    Second Class   Consumer  United States  ...        3     0.00  219.5820
# 2    Second Class  Corporate  United States  ...        2     0.00    6.8714
# 3  Standard Class   Consumer  United States  ...        5     0.45 -383.0310
# 4  Standard Class   Consumer  United States  ...        2     0.20    2.5164
#
# [5 rows x 13 columns]

# %%
Df.tail()
# Out:
#            Ship Mode   Segment        Country  ... Quantity Discount   Profit
# 9989    Second Class  Consumer  United States  ...        3      0.2   4.1028
# 9990  Standard Class  Consumer  United States  ...        2      0.0  15.6332
# 9991  Standard Class  Consumer  United States  ...        2      0.2  19.3932
# 9992  Standard Class  Consumer  United States  ...        4      0.0  13.3200
# 9993    Second Class  Consumer  United States  ...        2      0.0  72.9480
#
# [5 rows x 13 columns]

# %%
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %%
print(Df.shape)

## rows and columns
# Out:
# (9994, 13)

# %%
Df.isnull().sum()
# Out:
# Ship Mode       0
# Segment         0
# Country         0
# City            0
# State           0
# Postal Code     0
# Region          0
# Category        0
# Sub-Category    0
# Sales           0
# Quantity        0
# Discount        0
# Profit          0
# dtype: int64

# %%
Df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Ship Mode     9994 non-null   object
#  1   Segment       9994 non-null   object
#  2   Country       9994 non-null   object
#  3   City          9994 non-null   object
#  4   State         9994 non-null   object
#  5   Postal Code   9994 non-null   int64
#  6   Region        9994 non-null   object
#  7   Category      9994 non-null   object
#  8   Sub-Category  9994 non-null   object
#  9   Sales         9994 non-null   float64
#  10  Quantity      9994 non-null   int64
#  11  Discount      9994 non-null   float64
#  12  Profit        9994 non-null   float64
# dtypes: float64(3), int64(2), object(8)
# memory usage: 1015.1+ KB

# %%
Df.columns
# Out:
# Index(['Ship Mode', 'Segment', 'Country', 'City', 'State', 'Postal Code',
#        'Region', 'Category', 'Sub-Category', 'Sales', 'Quantity', 'Discount',
#        'Profit'],
#       dtype='object')

# %%
Df.nunique()
# Out:
# Ship Mode          4
# Segment            3
# Country            1
# City             531
# State             49
# Postal Code      631
# Region             4
# Category           3
# Sub-Category      17
# Sales           5825
# Quantity          14
# Discount          12
# Profit          7287
# dtype: int64

# %%
numerical_features = [feature for feature  in Df.columns if Df[feature].dtypes !='O']
print(len(numerical_features))
Df[numerical_features].head()
##o=object
# Out:
# 5
#    Postal Code     Sales  Quantity  Discount    Profit
# 0        42420  261.9600         2      0.00   41.9136
# 1        42420  731.9400         3      0.00  219.5820
# 2        90036   14.6200         2      0.00    6.8714
# 3        33311  957.5775         5      0.45 -383.0310
# 4        33311   22.3680         2      0.20    2.5164

# %%
corr=Df.corr()

# %%
corr
# Out:
#              Postal Code     Sales  Quantity  Discount    Profit
# Postal Code     1.000000 -0.023854  0.012761  0.058443 -0.029961
# Sales          -0.023854  1.000000  0.200795 -0.028190  0.479064
# Quantity        0.012761  0.200795  1.000000  0.008623  0.066253
# Discount        0.058443 -0.028190  0.008623  1.000000 -0.219487
# Profit         -0.029961  0.479064  0.066253 -0.219487  1.000000

# %%
Df = Df.drop(['Postal Code'],axis = 1)

# %%
Df['Ship Mode'].value_counts()
# Out:
# Standard Class    5968
# Second Class      1945
# First Class       1538
# Same Day           543
# Name: Ship Mode, dtype: int64

# %%
sns.countplot(x=Df['Ship Mode'])

# %% [markdown]
# #Observation
# >>The count of Standard Class is more than Second

# %%
Df['Ship Mode'].value_counts().plot.pie()
plt.show()

# %%
sns.countplot(x = 'Segment',data = Df, palette = 'rainbow')

# %% [markdown]
# # Observation
# >>The count of Home Office is far less than Consumer count.

# %%
Df['Segment'].value_counts().plot.pie()

# %%
Df['Category'].value_counts()
# Out:
# Office Supplies    6026
# Furniture          2121
# Technology         1847
# Name: Category, dtype: int64

# %%
sns.countplot(x='Category',data=Df,palette='tab10')

# %% [markdown]
# # Observation
# >>The count of Office supplies category is more than Furniture count and Technology.

# %%
Df['Category'].value_counts().plot.pie()

# %%
Df['Sub-Category'].value_counts()
# Out:
# Binders        1523
# Paper          1370
# Furnishings     957
# Phones          889
# Storage         846
# Art             796
# Accessories     775
# Chairs          617
# Appliances      466
# Labels          364
# Tables          319
# Envelopes       254
# Bookcases       228
# Fasteners       217
# Supplies        190
# Machines        115
# Copiers          68
# Name: Sub-Category, dtype: int64

# %%
sns.countplot(x=Df['Sub-Category'])
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# # Observation
# >>In Sub-Category Binders having highest count and Copiers having least count.

# %%
plt.figure(figsize=(15,12))
Df['Sub-Category'].value_counts().plot.pie()
plt.show()

# %%
Df['State'].value_counts()
# Out:
# California              2001
# New York                1128
# Texas                    985
# Pennsylvania             587
# Washington               506
# Illinois                 492
# Ohio                     469
# Florida                  383
# Michigan                 255
# North Carolina           249
# Arizona                  224
# Virginia                 224
# Georgia                  184
# Tennessee                183
# Colorado                 182
# Indiana                  149
# Kentucky                 139
# Massachusetts            135
# New Jersey               130
# Oregon                   124
# Wisconsin                110
# Maryland                 105
# Delaware                  96
# Minnesota                 89
# Connecticut               82
# Missouri                  66
# Oklahoma                  66
# Alabama                   61
# Arkansas                  60
# Rhode Island              56
# Utah                      53
# Mississippi               53
# ...

# %%
plt.figure(figsize=(15,15))
sns.countplot(y=Df['State'])
##plt.yticks(rotation=90)
plt.show()

# %% [markdown]
# # Observation
# >>California is having the highest count and West Virginia having the least count.

# %%
Df.hist(figsize=(10,10),bins=50)
plt.show()

# %% [markdown]
# ### **Observations**
# >>Most customers tends to buy quantity of 2 and 3
#
# >>Discount give maximum is 0 to 20 percent

# %%
Df['Region'].value_counts()
# Out:
# West       3203
# East       2848
# Central    2323
# South      1620
# Name: Region, dtype: int64

# %%
Df['Region'].value_counts().plot.pie()
plt.show()

# %% [markdown]
# # Profit vs Sales

# %%
plt.figure(figsize=(10,8))

sns.lineplot(x='Sales',y='Profit',label='Profit',data=Df)
plt.legend()
plt.show()

# %% [markdown]
# # Profit vs Quantity

# %%
sns.lineplot(x='Quantity',y='Profit',label='Profit',data=Df)
plt.legend()
plt.show()

# %% [markdown]
# # Observation
# >>There is no correlation between profit and quantity.

# %%
sns.lineplot(x='Discount',y='Profit',label='Profit',data=Df)
plt.legend()
plt.show()

# %% [markdown]
# ## **Obsevation**
# No Correlatoin between Profit and Discount

# %% [markdown]
# # Profit and Sales vs Segment

# %%
Df.groupby('Segment')[['Profit','Sales']].sum().plot.bar(color=['blue','red'],figsize=(8,5))
plt.ylabel('Profit/Loss and sales')
plt.show()

# %% [markdown]
# ### Observation
# Profit and sales are maximum in consumer segment and minimum in Home Office segment

# %% [markdown]
# # Quantitiy and Sales vs Segment

# %%
Df.groupby('Segment')[['Sales','Quantity']].sum().plot.bar(color=['pink','blue'],figsize=(8,5))
plt.ylabel('Quantity and sales')
plt.show()

# %% [markdown]
# # Observation
# >>Quantity and sales are maximum in Consumer Segment and minimum in Home Office Segment.

# %% [markdown]
# # Segment wise Sales in each Region

# %%
plt.figure(figsize=(12,8))
plt.title('Segment wise Sales in each Region')
sns.barplot(x='Region',y='Sales',data=Df,hue='Segment',order=Df['Region'].value_counts().index,palette='rocket')
plt.xlabel('Region',fontsize=15)
plt.show()

# %% [markdown]
# ## **Observation**
# Segment wise sales are almost same in every region

# %% [markdown]
# # Profit and Sales vs Region

# %%
Df.groupby('Region')[['Profit','Sales']].sum().plot.bar(color=['blue','red'],figsize=(8,5))
plt.ylabel('Profit/Loss and sales')
plt.show()

# %% [markdown]
# ### **Observation**
# Profit and sales are maximum in west region and minimum in south region

# %% [markdown]
# #Profit and Sales vs Category

# %%
Df.groupby('Category')[['Profit','Sales']].sum().plot.bar(color=['blue','red'],figsize=(8,5))
plt.ylabel('Profit/Loss and sales')
plt.show()

# %% [markdown]
# ### Observation
# Technology and Office Supplies have high profit.
# Furniture have less profit

# %% [markdown]
# # Profit and Sales vs Sub-Category

# %%
plt.figure(figsize=(12,12))
Df.groupby('Sub-Category')[['Profit','Sales']].sum().plot.bar(color=['blue','red'],figsize=(10,8))
plt.ylabel('Profit/Loss and sales')
plt.show()

# %% [markdown]
# ### Observation
# Phones sub-category have high sales.
#
# Chairs have high sales but less profit compared to phones
#
# Tables and Bookmarks sub-categories facing huge loss

# %% [markdown]
# # Profit and Sales vs State

# %%
plt.figure(figsize=(12,12))

Df.groupby('State')[['Profit','Sales']].sum().plot.bar(color=['blue','red'],figsize=(14,8))
plt.ylabel('Profit/Loss and sales')
plt.show()

# %% [markdown]
# ### Observation
# High profit is for california, new york
#
# Loss is for texas, pennsylvania, Ohio

# %% [markdown]
# # Quantity and Sales vs State

# %%
plt.figure(figsize=(12,12))

Df.groupby('State')[['Quantity','Sales']].sum().plot.bar(color=['blue','red'],figsize=(14,8))
plt.ylabel('Quantity and sales')
plt.show()

# %% [markdown]
# # Observation
# >>California have highest sales and least Wyoming.

# %% [markdown]
# # Quantity and Sales vs Ship Mode

# %%
plt.figure(figsize=(12,12))

Df.groupby('Ship Mode')[['Quantity','Sales']].sum().plot.bar(color=['blue','red'],figsize=(14,8))
plt.ylabel('Quantity and sales')
plt.show()

# %% [markdown]
# # Observation
# >> Quantity and sales are more in Standard class
